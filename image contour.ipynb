# %%
# used for shape k  analyse,detection,and recognization 
# jb tk isko continue point milte rhega wo img print krte rhega


import cv2
import numpy as np

img=cv2.imread("C:\\Users\\puni\\Desktop\\op.png")
img=cv2.resize(img,(300,300))
img1=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

ret,thres=cv2.threshold(img1,70,255,0)
# contour (img,contour retrival,method)  ye only coordinate dega
cntr,hier=cv2.findContours(thres,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
print(cntr,len(cntr))


#ab cntr point (coordinate) se img draw krte hai
img=cv2.drawContours(img,cntr,-1,(130,10,15),8)
               
cv2.imshow("main",img)
cv2.imshow("black and white",img1)
cv2.imshow("threshold",thres)

cv2.imshow("main",cntrimg)
               
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# [array([[[190, 110]],
#
#        [[189, 111]],
#
#        [[188, 111]],
#
#        [[187, 112]],
#
#        [[186, 112]],
#
#        [[185, 113]],
#
#        [[184, 113]],
#
#        [[182, 115]],
#
#        [[181, 115]],
#
#        [[179, 117]],
#
#        [[178, 117]],
#
#        [[175, 120]],
#
#        [[174, 120]],
#
#        [[168, 126]],
#
#        [[168, 127]],
#
#        [[165, 130]],
#
#        [[165, 131]],
#
#        [[163, 133]],
#
#        [[163, 134]],
#
#        [[162, 135]],
#
#        [[162, 136]],
#
#        [[161, 137]],
#
#        [[161, 138]],
#
#        [[160, 139]],
#
#        [[160, 140]],
#
#        [[159, 141]],
#
#        [[159, 143]],
#
#        [[158, 144]],
#
#        [[158, 148]],
#
#        [[157, 149]],
#
#        [[157, 163]],
#
#        [[158, 164]],
#
#        [[158, 167]],
#
#        [[159, 168]],
#
#        [[159, 170]],
#
#        [[160, 171]],
#
#        [[160, 172]],
#
#        [[161, 173]],
#
#        [[161, 175]],
#
#        [[163, 177]],
# ...
